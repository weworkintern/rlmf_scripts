# %% [markdown]
# # Run scripts on ALL batches

# %% [markdown]
# ## Use cases:
# - Extract abandoned cases
# - Extract effective cases
# - Extract metadata

# %%
import json
import os
import glob
import pandas as pd

COLUMN_MAPPING = {
    'task id': 'task_id',
    'trainer id': 'trainer_id',
    'model name': 'model_name',
    'question_id': 'question_id',
    'system prompt': 'system_prompt',
    'user prompt': 'user_prompt',
    'level': 'level',
    'ACC': 'acc',
    'intervene_system_prompt': 'intervene_system_prompt',
    'intervene prompt': 'intervene_prompt',
    'ground_truth_answer': 'ground_truth_answer',
    'temperature': 'temperature',
    'total_tokens': 'total_tokens',
    'total_latency (ms)': 'total_latency_ms',
    'initial_reasoning': 'initial_reasoning',
    'response': 'response',
    # 'initial_response': 'initial_response',
    'final_answer': 'final_answer',
    'abandon_prompt': 'abandon_prompt',
    'abandon_prompt_reason': 'abandon_prompt_reason',
    'intervention rounds': 'intervention_rounds',
    'CoT quality': 'cot_quality',
    'remarks': 'remarks',
    'Model performance classification': 'model_performance_classification',
    'codeforces_submission_id':'codeforces_submission_id',
    'programming_language': 'programming_language',
}

DATA_DIRECTORY = '/Users/bytedance/Workspace/project_rlmf/data/ALL'

def process_json_files(data_dir):
    all_processed_items = []
    all_column_names = set(COLUMN_MAPPING.values()) # Start with mapped names

    # Recursively find all .json and .jsonl files
    json_files = glob.glob(os.path.join(data_dir, '**', '*.json'), recursive=True)
    jsonl_files = glob.glob(os.path.join(data_dir, '**', '*.jsonl'), recursive=True)
    all_input_files = json_files + jsonl_files

    for file_path in all_input_files:
        print(f"Processing file: {file_path}")
        # Extract batch_id from filename
        basename = os.path.basename(file_path)
        batch_id = os.path.splitext(basename)[0]
        
        items = []
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                if file_path.endswith('.jsonl'):
                    for line in f:
                        try:
                            items.append(json.loads(line))
                        except json.JSONDecodeError as e_line:
                            print(f"Skipping line in {file_path} due to JSON decode error: {e_line}")
                elif file_path.endswith('.json'):
                    try:
                        content = json.load(f)
                        if isinstance(content, list):
                            items = content
                        elif isinstance(content, dict): # Handle case where a .json file might contain a single object
                            items = [content]
                        else:
                            print(f"Skipping file {file_path}: content is not a list or dict of JSON objects.")
                    except json.JSONDecodeError as e_file:
                        print(f"Skipping file {file_path} due to JSON decode error: {e_file}")
                        # As a fallback for .json, try to read as JSONL if initial parse fails
                        # This might happen if a .json file is actually in JSONL format
                        f.seek(0) # Reset file pointer to the beginning
                        try:
                            print(f"Attempting to read {file_path} as JSONL...")
                            current_items = []
                            for line in f:
                                try:
                                    current_items.append(json.loads(line))
                                except json.JSONDecodeError as e_line_fallback:
                                    print(f"Skipping line in {file_path} (fallback JSONL) due to JSON decode error: {e_line_fallback}")
                            items = current_items
                        except Exception as e_fallback:
                            print(f"Failed to read {file_path} as JSONL fallback: {e_fallback}")

        except Exception as e:
            print(f"Could not read or process file {file_path}: {e}")
            continue

        for item in items:
            if not isinstance(item, dict):
                print(f"Skipping non-dictionary item in {file_path}: {item}")
                continue
            
            processed_item = {}
            # Apply column mapping and collect all original column names
            for original_key, value in item.items():
                if original_key in COLUMN_MAPPING:
                    new_key = COLUMN_MAPPING.get(original_key, original_key) # Use original key if not in mapping
                    if 'id' in new_key:  # Convert any form of ID to string
                        value = str(value)
                    processed_item[new_key] = value
                    all_column_names.add(new_key) # Add the key used (either mapped or original)
            
            # Add batch_id
            processed_item['batch_id'] = batch_id
            all_column_names.add('batch_id')
            
            all_processed_items.append(processed_item)

    # # Filter "Abandoned Cases" (where `abandon_prompt` == "Yes")
    # filtered_items = [
    #     item for item in all_processed_items 
    #     if isinstance(item.get('abandon_prompt'), str) and item.get('abandon_prompt').lower() == 'yes'
    # ]

    # Filter "Effective Labels" (where `abandon_prompt` == "No" and `intervention_rounds` > 0)
    filtered_items = [
        item for item in all_processed_items 
            if 
                (isinstance(item.get('abandon_prompt'), str) and item.get('abandon_prompt').lower() == 'no' and int(item.get('intervention_rounds')) > 0)
                and 
                item.get('task_id') != '69492'  # known problematic task with hard-coded solution (from Batch 20)
    ]

    # # No filter
    # filtered_items = all_processed_items

    # Ensure all filtered items have all collected columns
    final_output_items = []
    for item in filtered_items:
        standardized_item = {}
        for col_name in all_column_names:
            standardized_item[col_name] = item.get(col_name) # Defaults to None if key is missing
        final_output_items.append(standardized_item)
        
    return final_output_items

# Ensure the DATA_DIRECTORY exists
if not os.path.isdir(DATA_DIRECTORY):
    raise ValueError(f"Error: Data directory '{DATA_DIRECTORY}' not found.")
else:
    output_data = process_json_files(DATA_DIRECTORY)

if output_data:
    # print(f"\nFound {len(output_data)} items with 'abandon_prompt' == 'Yes'.")
    print(f"\nFound {len(output_data)} items.")
    print("Details of the first item (if any):")
    print(json.dumps(output_data[0], indent=4))
    
    # # Save the output_data to 'abandoned.json'
    # output_file_path = os.path.join(DATA_DIRECTORY, 'abandoned.json')
    # try:
    #     with open(output_file_path, 'w', encoding='utf-8') as outfile:
    #         json.dump(output_data, outfile, indent=4)
    #     print(f"\nOutput successfully written to {output_file_path}")
    # except IOError as e:
    #     print(f"\nError writing output to {output_file_path}: {e}")

    # Save the output_data to 'effective_labels_611.json'
    output_file_path = os.path.join(DATA_DIRECTORY, '250626_rlmf_effective_labels_609.json')
    try:
        with open(output_file_path, 'w', encoding='utf-8') as outfile:
            json.dump(output_data, outfile, indent=4)
        print(f"\nOutput successfully written to {output_file_path}")
    except IOError as e:
        print(f"\nError writing output to {output_file_path}: {e}")

    # # Save the output_data to 'metadata.json'
    # df = pd.DataFrame(output_data)

    # # Reorder the DataFrame columns
    # final_ordered_columns = list(COLUMN_MAPPING.values()) + ['batch_id']
    # df = df[final_ordered_columns]

    # output_file_path = os.path.join(DATA_DIRECTORY, 'metadata.csv')
    # try:
    #     df.to_csv(output_file_path, index=False, encoding='utf-8')
    #     print(f"\nOutput successfully written to {output_file_path}")
    # except IOError as e:
    #     print(f"\nError writing output to {output_file_path}: {e}")
    
else:
    # print("No items found with 'abandon_prompt' == 'Yes'.")
    print("No items found.")
# Out:
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 23062025_21_V1_02.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 13062025_14_V2_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 10062025_11_V2_61.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 02052025_3_V2_36.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 05062025_9_V2_100.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 17062025_16_V1_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 24062025_23_V1_39.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 20062025_20_V1_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 23062025_22_V1_51.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 12062025_13_V2_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 09062025_10_V2_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 04062025_8_V2_100.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 16052025_5_V2_105.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 20062025_19_V1_3.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 19062025_18_V1_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 25062025_24_V1_50.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 11062025_12_V2_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 30052025_7_V2_200.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 15052025_4_V3_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 16062025_15_V1_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 18062025_17_V1_60.json
# Processing file: /Users/bytedance/Workspace/project_rlmf/data/ALL/RLMF 30052025_6_V5_167.json
#
# Found 608 items.
# Details of the first item (if any):
# {
#     "system_prompt": "You are an expert problem solver who provides clear, comprehensive, step-by-step solutions to competitive programming problems. You are given the original problem statement, followed by the desired programming language that you have to use in your solution code. Your task is to produce a complete, structured solution in the requested programming language.\\nProvide everything (reasoning and response) in \\u82f1\\u8bed, literally everything should be written in English. \\nIf the programming language is specified in the problem description, use it in the reasoning and the response (solution code). Otherwise, default to C++. \\nStrictly you need to generate final response and reasoning.",
#     "programming_language": "C++",
#     "total_tokens": 1303,
#     "batch_id": "RLMF 23062025_21_V1_02",
#     "level": null,
#     "acc": 0.0,
#     "model_name": "ep-20250531134931-xwct7",
#     "task_id": "69604",
#     "initial_reasoning": "Got it, let's start by correcting the approach and then writing the code. First, I need to remember the key insight from similar problems: each swap operation on k allows us to choose whether the k-th row is the original row or the original column. But since swapping k affects both row k and column k, we need to model dependencies between indices using a parity DSU (Union-Find with bipartition) to track whether two indices must have the same or opposite parity (swap state).\\\\n\\\\nWait, let's go back to the problem's core. The operation swaps row k with column k. Let's think about what this means for the final matrix. For any cell (i, j), after some swaps, its value can be either A[i][j] or A[j][i], but with constraints: if (i, j) uses A[j][i], then (j, i) must use A[i][j], and vice versa. Also, for cells (i, k) and (k, j), the choices must be consistent (e.g., if i and k have a parity constraint, and k and j have another, then i and j's constraint is determined).\\\\n\\\\nThe correct approach, as per competitive programming solutions for similar problems (like matrix lex smallest with swap constraints), is:\\\\n\\\\n1. **Model Constraints**: For each pair (i, j), if we decide that the final cell (i, j) should be the minimum of A[i][j] and A[j][i], we need to enforce the corresponding parity constraint (same or different) between i and j. However, we must process these constraints in a way that ensures global consistency.\\\\n\\\\nWait, no\\u2014actually, the correct way is to realize that the matrix elements form a graph where each cell (i, j) (i < j) connects i and j with an edge that has a \\\\\"preference\\\\\" (whether we want i and j to have the same or different parity to get the minimum value). But since we need lex smallest, we process cells in row-major order, and for each cell (i, j), we make the minimal choice possible given the current constraints.\\\\n\\\\nBut let's look at the sample input 1:\\\\n\\\\nOriginal matrix:\\\\n2 1 2\\\\n2 1 2\\\\n1 1 2\\\\n\\\\nSample output:\\\\n2 1 1\\\\n2 1 1\\\\n2 2 2\\\\n\\\\nLet's see cell (1,3): original A[1][3] is 2, A[3][1] is 1. To get the minimal value (1), we need to swap row 3 (so that (1,3) takes A[3][1]). Which aligns with the sample operation.\\\\n\\\\nAh, right! So for cell (i, j), if we want B[i][j] to be the minimum of A[i][j] and A[j][i], we need to set the parity of i and j such that:\\\\n\\\\n- If min_val is A[i][j], then parity[i] == parity[j] (since B[i][j] = A[i][j] when same parity).\\\\n- If min_val is A[j][i], then parity[i] != parity[j] (since B[i][j] = A[j][i] when different parity).\\\\n\\\\nBut we must ensure that these choices are consistent across the matrix. For example, if we choose parity[i] != parity[j] for cell (i, j), then for cell (j, k), our choice must not contradict this.\\\\n\\\\nSo the steps are:\\\\n\\\\n1. **Parity DSU**: Use a DSU that tracks the parity (relative to root) for each node. This allows us to check if a constraint (same or different parity) between two nodes is possible.\\\\n\\\\n2. **Process Cells in Row-Major Order**: For each cell (i, j) in row-major order (from (1,1) to (n,n)):\\\\n\\\\n   a. If i == j: B[i][j] = A[i][j] (since parity[i] == parity[i] always).\\\\n   b. If i > j: B[i][j] is determined by B[j][i] and the parity of i and j. Specifically, if parity[i] == parity[j], then B[i][j] = A[i][j]; else, B[i][j] = A[j][i]. But wait, no\\u2014since (i, j) is the transpose of (j, i), once we process (j, i), (i, j) is determined. So we can skip processing (i, j) when i > j.\\\\n   c. If i < j: We want to choose B[i][j] to be the minimal possible value (min(A[i][j], A[j][i])), but only if this choice is consistent with existing constraints. If it's not, we have to take the other value. Then, we enforce the corresponding constraint (same or different parity) between i and j using the DSU.\\\\n\\\\n3. **Build the Result Matrix**: After determining all parity constraints, construct the result mat ...
#     "ground_truth_answer": "#include <iostream>\\n#include <vector>\\n#include <utility>\\n#include <algorithm>\\nusing namespace std;\\n\\nstruct ParityDSU {\\n    vector<int> parent;\\n    vector<int> rank;\\n    vector<int> color; // 0: same parity as parent, 1: different\\n\\n    ParityDSU(int n) {\\n        parent.resize(n);\\n        rank.resize(n, 0);\\n        color.resize(n, 0);\\n        for (int i = 0; i < n; ++i) {\\n            parent[i] = i;\\n        }\\n    }\\n\\n    pair<int, int> find(int u) {\\n        if (parent[u] != u) {\\n            auto [root, c] = find(parent[u]);\\n            parent[u] = root;\\n            color[u] ^= c;\\n        }\\n        return {parent[u], color[u]};\\n    }\\n\\n    bool unite(int u, int v, int req) {\\n        auto [root_u, cu] = find(u);\\n        auto [root_v, cv] = find(v);\\n        if (root_u == root_v) {\\n            return (cu ^ cv) == req;\\n        }\\n        if (rank[root_u] < rank[root_v]) {\\n            swap(root_u, root_v);\\n            swap(cu, cv);\\n            swap(u, v);\\n        }\\n        parent[root_v] = root_u;\\n        color[root_v] = cu ^ cv ^ req;\\n        if (rank[root_u] == rank[root_v]) {\\n            rank[root_u]++;\\n        }\\n        return true;\\n    }\\n};\\n\\nint main() {\\n    ios_base::sync_with_stdio(false);\\n    cin.tie(nullptr);\\n    int t;\\n    cin >> t;\\n    while (t--) {\\n        int n;\\n        cin >> n;\\n        vector<vector<long long>> A(n, vector<long long>(n));\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = 0; j < n; ++j) {\\n                cin >> A[i][j];\\n            }\\n        }\\n\\n        if (n == 1) {\\n            cout << A[0][0] << '\\\\n';\\n            continue;\\n        }\\n\\n        ParityDSU dsu(n);\\n\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = i + 1; j < n; ++j) {\\n                long long val_same = A[i][j];\\n                long long val_diff = A[j][i];\\n                if (val_same == val_diff) {\\n                    continue;\\n                }\\n                long long min_val = min(val_same, val_diff);\\n                int req = (min_val == val_same) ? 0 : 1;\\n                auto [root_i, ci] = dsu.find(i);\\n                auto [root_j, cj] = dsu.find(j);\\n                if (root_i != root_j) {\\n                    dsu.unite(i, j, req);\\n                }\\n            }\\n        }\\n\\n        vector<vector<long long>> B(n, vector<long long>(n));\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = 0; j < n; ++j) {\\n                if (i == j) {\\n                    B[i][j] = A[i][j];\\n                    continue;\\n                }\\n                auto [root_i, ci] = dsu.find(i);\\n                auto [root_j, cj] = dsu.find(j);\\n                int parity = ci ^ cj;\\n                B[i][j] = (parity == 0) ? A[i][j] : A[j][i];\\n            }\\n        }\\n\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = 0; j < n; ++j) {\\n                cout << B[i][j] << \" \";\\n            }\\n            cout << '\\\\n';\\n        }\\n    }\\n    return 0;\\n}",
#     "response": "Got it, let's start by correcting the approach and then writing the code. First, I need to remember the key insight from similar problems: each swap operation on k allows us to choose whether the k-th row is the original row or the original column. But since swapping k affects both row k and column k, we need to model dependencies between indices using a parity DSU (Union-Find with bipartition) to track whether two indices must have the same or opposite parity (swap state).\\\\n\\\\nWait, let's go back to the problem's core.\\nThe operation swaps row k with column k. Let's think about what this means for the final matrix.\\nFor any cell (i, j), after some swaps, its value can be either A[i][j] or A[j][i], but with constraints: if (i, j) uses A[j][i], then (j, i) must use A[i][j], and vice versa. Also, for cells (i, k) and (k, j), the choices must be consistent (e.g., if i and k have a parity constraint, and k and j have another, then i and j's constraint is determined).\\\\n\\\\nThe correct approach, as per competitive programming solutions for similar problems (like matrix lex smallest with swap constraints), is:\\\\n\\\\n1. **Model Constraints**: For each pair (i, j), if we decide that the final cell (i, j) should be the minimum of A[i][j] and A[j][i], we need to enforce the corresponding parity constraint (same or different) between i and j.\\nHowever, we must process these constraints in a way that ensures global consistency.\\\\n\\\\nWait, no\\u2014actually, the correct way is to realize that the matrix elements form a graph where each cell (i, j) (i < j) connects i and j with an edge that has a \\\\\"preference\\\\\" (whether we want i and j to have the same or different parity to get the minimum value).\\nBut since we need lex smallest, we process cells in row-major order, and for each cell (i, j), we make the minimal choice possible given the current constraints.\\\\n\\\\nBut let's look at the sample input 1:\\\\n\\\\nOriginal matrix:\\\\n2 1 2\\\\n2 1 2\\\\n1 1 2\\\\n\\\\nSample output:\\\\n2 1 1\\\\n2 1 1\\\\n2 2 2\\\\n\\\\nLet's see cell (1,3): original A[1][3] is 2, A[3][1] is 1. To get the minimal value (1), we need to swap row 3 (so that (1,3) takes A[3][1]). Which aligns with the sample operation.\\\\n\\\\nAh, right! So for cell (i, j), if we want B[i][j] to be the minimum of A[i][j] and A[j][i], we need to set the parity of i and j such that:\\\\n\\\\n- If min_val is A[i][j], then parity[i] == parity[j] (since B[i][j] = A[i][j] when same parity).\\\\n- If min_val is A[j][i], then parity[i] != parity[j] (since B[i][j] = A[j][i] when different parity).\\\\n\\\\nBut we must ensure that these choices are consistent across the matrix.\\nFor example, if we choose parity[i] != parity[j] for cell (i, j), then for cell (j, k), our choice must not contradict this.\\\\n\\\\nSo the steps are:\\\\n\\\\n1. **Parity DSU**: Use a DSU that tracks the parity (relative to root) for each node.\\nThis allows us to check if a constraint (same or different parity) between two nodes is possible.\\\\n\\\\n2. **Process Cells in Row-Major Order**: For each cell (i, j) in row-major order (from (1,1) to (n,n)):\\\\n\\\\n   a. If i == j: B[i][j] = A[i][j] (since parity[i] == parity[i] always).\\\\n   b. If i > j: B[i][j] is determined by B[j][i] and the parity of i and j. Specifically, if parity[i] == parity[j], then B[i][j] = A[i][j]; else, B[i][j] = A[j][i]. But wait, no\\u2014since (i, j) is the transpose of (j, i), once we process (j, i), (i, j) is determined. So we can skip processing (i, j) when i > j.\\\\n   c.\\nIf i < j: We want to choose B[i][j] to be the minimal possible value (min(A[i][j], A[j][i])), but only if this choice is consistent with existing constraints. If it's not, we have to take the other value. Then, we enforce the corresponding constraint (same or different parity) between i and j using the DSU.\\\\n\\\\n3. **Build the Result Matrix**: After determining all parity constraints, construct the resul ...
#     "user_prompt": "Solving the given programming contest with a C++ solution.\\n\\n Problem Description\\nYou are given a square matrix \\\\\\\\(A\\\\\\\\) of size \\\\\\\\(n \\\\times n\\\\\\\\) whose elements are integers. We will denote the element on the intersection of the \\\\\\\\(i\\\\\\\\)-th row and the \\\\\\\\(j\\\\\\\\)-th column as \\\\\\\\(A_{i,j}\\\\\\\\).\\n\\nYou can perform operations on the matrix. In each operation, you can choose an integer \\\\\\\\(k\\\\\\\\), then for each index \\\\\\\\(i\\\\\\\\) (\\\\\\\\(1 \\\\leq i \\\\leq n\\\\\\\\)), swap \\\\\\\\(A_{i, k}\\\\\\\\) with \\\\\\\\(A_{k, i}\\\\\\\\). Note that cell \\\\\\\\(A_{k, k}\\\\\\\\) remains unchanged.\\n\\nFor example, for \\\\\\\\(n = 4\\\\\\\\) and \\\\\\\\(k = 3\\\\\\\\), this matrix will be transformed like this:\\n\\n\\\\begin{center}\\n  \\\\includegraphics[scale=0.6]{grid.png} \\\\\\\\\\n  \\\\small{The operation \\\\\\\\(k = 3\\\\\\\\) swaps the blue row with the green column.}\\n\\\\end{center}\\n\\nYou can perform this operation any number of times. Find the lexicographically smallest matrix\\\\\\\\(^\\\\dagger\\\\\\\\) you can obtain after performing arbitrary number of operations.\\n\\n\\\\\\\\({}^\\\\dagger\\\\\\\\) For two matrices \\\\\\\\(A\\\\\\\\) and \\\\\\\\(B\\\\\\\\) of size \\\\\\\\(n \\\\times n\\\\\\\\), let \\\\\\\\(a_{(i-1) \\\\cdot n + j} = A_{i,j}\\\\\\\\) and \\\\\\\\(b_{(i-1) \\\\cdot n + j} = B_{i,j}\\\\\\\\). Then, the matrix \\\\\\\\(A\\\\\\\\) is lexicographically smaller than the matrix \\\\\\\\(B\\\\\\\\) when there exists an index \\\\\\\\(i\\\\\\\\) (\\\\\\\\(1 \\\\leq i \\\\leq n^2\\\\\\\\)) such that \\\\\\\\(a_i < b_i\\\\\\\\) and for all indices \\\\\\\\(j\\\\\\\\) such that \\\\\\\\(1 \\\\leq j < i\\\\\\\\), \\\\\\\\(a_j = b_j\\\\\\\\).\\n\\n Input Format\\nThe first line contains a single integer \\\\\\\\(t\\\\\\\\) (\\\\\\\\(1 \\\\leq t \\\\leq 10^5\\\\\\\\)) --- the number of test cases.\\n\\nThe first line of each test case contains a single integer \\\\\\\\(n\\\\\\\\) (\\\\\\\\(1 \\\\leq n \\\\leq 1000\\\\\\\\)) --- the size of the matrix.\\n\\nThe \\\\\\\\(i\\\\\\\\)-th line of the next \\\\\\\\(n\\\\\\\\) lines contains \\\\\\\\(n\\\\\\\\) integers \\\\\\\\(A_{i, 1}, A_{i, 2}, \\\\dots, A_{i, n}\\\\\\\\) (\\\\\\\\(1 \\\\le A_{i, j} \\\\le 10^9\\\\\\\\)) --- description of the matrix \\\\\\\\(A\\\\\\\\).\\n\\nIt is guaranteed that the sum of \\\\\\\\(n^2\\\\\\\\) over all test cases does not exceed \\\\\\\\(10^6\\\\\\\\).\\n\\n\\n Output Format\\nFor each test case, print \\\\\\\\(n\\\\\\\\) lines with \\\\\\\\(n\\\\\\\\) integers each --- the lexicographically smallest matrix.\\n\\n Sample Input\\n2\\n3\\n2 1 2\\n2 1 2\\n1 1 2\\n4\\n3 3 1 2\\n1 1 3 1\\n3 2 3 2\\n2 3 3 1\\n\\n Sample Output\\n2 1 1\\n2 1 1\\n2 2 2\\n3 1 1 2\\n3 1 2 1\\n3 3 3 3\\n2 3 2 1\\n\\n\\n Notes\\nNote that in every picture below the matrix is transformed in such a way that the blue rows are swapped with the green columns.\\n\\nIn the first test case, we can perform \\\\\\\\(1\\\\\\\\) operation for \\\\\\\\(k = 3\\\\\\\\). The matrix will be transformed as below:\\n\\\\begin{center}\\n  \\\\includegraphics[scale=0.6]{ex1.png}\\n\\\\end{center}\\nIn the second test case, we can perform \\\\\\\\(2\\\\\\\\) operations for \\\\\\\\(k = 1\\\\\\\\) and \\\\\\\\(k = 3\\\\\\\\):\\n\\\\begin{center}\\n  \\\\includegraphics[scale=0.6]{ex2.png}\\n\\\\end{center}\\n\\\\begin{center}\\n  \\\\includegraphics[scale=0.6]{ex3.png}\\n\\\\end{center}\\n\\nYou are a C++ developer solving the above competitive\\nprogramming problem described above in detail.\\nYour final output must be a complete and self-contained\\nsolution written only in modern C++ (C++14 or later).\\nFollow these rules:\\nProvide the most efficient solution.\\nUse only C++ in both your reasoning and code.\\nDo not explain using other programming languages.\\nUse clear and expressive variable names.\\nInclude inline comments and/or a function-level\\ndescription to ex ...
#     "model_performance_classification": "Model response is incorrect but can be corrected with intervention",
#     "codeforces_submission_id": "325591640",
#     "final_answer": "To solve this problem, we need to find the lexicographically smallest matrix achievable through a series of allowed operations. Each operation swaps the k-th row with the k-th column, and we can perform this any number of times. The key insight is to model the problem using a Union-Find (Disjoint Set Union, DSU) structure that tracks parity constraints between indices to ensure consistency.\\n\\n### Approach\\n1. **Parity DSU**: Use a DSU with bipartition (parity tracking) to manage constraints between indices. This helps determine if two indices should have the same or different parity (swap state) to achieve the smallest value.\\n2. **Constraint Processing**: For each pair of indices (i, j) where i < j (processed in row-major order to prioritize lexicographically earlier cells), enforce constraints to choose the smallest possible value. If the values at (i, j) and (j, i) are different, we link the indices with a parity constraint to prefer the smaller value.\\n3. **Matrix Construction**: After finalizing all constraints, construct the result matrix using the parity information from the DSU. For each cell (i, j), use the parity of i and j to decide whether to keep the original value or swap with (j, i).\\n\\n### Solution Code\\n```cpp\\n#include <iostream>\\n#include <vector>\\n#include <utility>\\n#include <algorithm>\\nusing namespace std;\\n\\nstruct ParityDSU {\\n    vector<int> parent;\\n    vector<int> rank;\\n    vector<int> color; // 0: same parity as parent, 1: different\\n\\n    ParityDSU(int n) {\\n        parent.resize(n);\\n        rank.resize(n, 0);\\n        color.resize(n, 0);\\n        for (int i = 0; i < n; ++i) {\\n            parent[i] = i;\\n        }\\n    }\\n\\n    pair<int, int> find(int u) {\\n        if (parent[u] != u) {\\n            auto [root, c] = find(parent[u]);\\n            parent[u] = root;\\n            color[u] ^= c;\\n        }\\n        return {parent[u], color[u]};\\n    }\\n\\n    bool unite(int u, int v, int req) {\\n        auto [root_u, cu] = find(u);\\n        auto [root_v, cv] = find(v);\\n        if (root_u == root_v) {\\n            return (cu ^ cv) == req;\\n        }\\n        if (rank[root_u] < rank[root_v]) {\\n            swap(root_u, root_v);\\n            swap(cu, cv);\\n            swap(u, v);\\n        }\\n        parent[root_v] = root_u;\\n        color[root_v] = cu ^ cv ^ req;\\n        if (rank[root_u] == rank[root_v]) {\\n            rank[root_u]++;\\n        }\\n        return true;\\n    }\\n};\\n\\nint main() {\\n    ios_base::sync_with_stdio(false);\\n    cin.tie(nullptr);\\n    int t;\\n    cin >> t;\\n    while (t--) {\\n        int n;\\n        cin >> n;\\n        vector<vector<long long>> A(n, vector<long long>(n));\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = 0; j < n; ++j) {\\n                cin >> A[i][j];\\n            }\\n        }\\n\\n        if (n == 1) {\\n            cout << A[0][0] << '\\\\n';\\n            continue;\\n        }\\n\\n        ParityDSU dsu(n);\\n\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = i + 1; j < n; ++j) {\\n                long long val_same = A[i][j];\\n                long long val_diff = A[j][i];\\n                if (val_same == val_diff) {\\n                    continue;\\n                }\\n                long long min_val = min(val_same, val_diff);\\n                int req = (min_val == val_same) ? 0 : 1;\\n                auto [root_i, ci] = dsu.find(i);\\n                auto [root_j, cj] = dsu.find(j);\\n                if (root_i != root_j) {\\n                    dsu.unite(i, j, req);\\n                }\\n            }\\n        }\\n\\n        vector<vector<long long>> B(n, vector<long long>(n));\\n        for (int i = 0; i < n; ++i) {\\n            for (int j = 0; j < n; ++j) {\\n                if (i == j) {\\n                    B[i][j] = A[i][j];\\n                    continue;\\n                }\\n                auto [root_i, ci] = dsu. ...
#     "abandon_prompt_reason": null,
#     "question_id": "Codeforces/1713E",
#     "cot_quality": "Good",
#     "remarks": "{'remarks': [{'intervene_index': 1, 'human_feedback': 'LC: 1, GC: 1; (I failed to ensure the consistency of parity constraints across all unions, leading to misapplied values and ultimately an incorrect matrix.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 2, 'human_feedback': 'LC: 2, GC: 2; (The current DSU logic fails to properly respect existing parity constraints between indices when they are already connected, leading to incorrect selections of minimal values between val0 and val1, ultimately resulting in an incorrect matrix.)', 'feedback_type': 'INCORRECT'}, {'intervene_index': 3, 'human_feedback': 'LC: 1, GC: 3; (The current DSU logic fails to properly respect existing parity constraints between indices when they are already connected, leading to contradictory parity assignments and ultimately causing the final matrix to violate the intended lexicographical order.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 4, 'human_feedback': 'LC: 2, GC: 4; (It wrongly applies new parity constraints without checking existing links, which leads to conflicts in the DSU and breaks the matrix construction.)', 'feedback_type': 'INCORRECT'}, {'intervene_index': 5, 'human_feedback': 'LC: 1, GC: 5; (Relies on parity values from DSU without validating their consistency; a single bad merge can cascade into widespread misselection across the matrix.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 6, 'human_feedback': 'LC: 1, GC: 6; (Relies on parity values from DSU without validating their consistency; a single bad merge can cascade into widespread misselection across the matrix.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 7, 'human_feedback': 'LC: 2, GC: 7; (Oh no, the logic assumes the parity structure is always reliable\u2014but even a single inconsistent merge can throw off every decision that follows, leading to incorrect matrix entries.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 8, 'human_feedback': 'LC: 1, GC: 8; (Umm, the step catches the conflict check idea, but doesn\u2019t clearly say how to handle failed compatibility. So the reasoning gets stuck when a parity contradiction arises.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 9, 'human_feedback': 'LC: 1, GC: 9; (It wrongly applies new parity constraints without checking existing links, which leads to conflicts in the DSU and breaks the matrix construction.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 10, 'human_feedback': 'LC: 1, GC: 10; (It wrongly applies new parity constraints without checking existing links, which leads to conflicts in the DSU and breaks the matrix construction.)', 'feedback_type': 'CRITICIZE'}, {'intervene_index': 11, 'human_feedback': 'LC: 2, GC: 11; (It wrongly applies new parity constraints without checking existing links, which leads to conflicts in the DSU and breaks the matrix construction.)', 'feedback_type': 'CRITICIZE'}]}",
#     "temperature": 1,
#     "trainer_id": "281",
#     "abandon_prompt": "No",
#     "intervention_rounds": 11,
#     "intervene_system_prompt": "You are an expert problem solver who provides clear, comprehensive, step-by-step solutions to competitive programming problems. You are provided with the Original_Problem, including the desired programming language that you have to use in your solution code, a Partial_Solution (consisting of the correct steps and a suggestion of a corrective direction to the reasoning). Your task is to follow up on the Partial_Solution and update the reasoning content by revising the self-criticism provided and generating any subsequent steps needed to complete the solution, while leaving the Partial_Solution unchanged.\\n\\nKeep in mind the following: \\nDo not restart the reasoning content or reframe it from scratch. Continue naturally from the provided Partial_Solution.\\nProvide everything (reasoning and response) in \\u82f1\\u8bed, literally everything should be written in English\\nIf the programming language is specified in the Original_Problem, use it in the reasoning and the response (solution code). Otherwise, default to C++.\\n\\nInput includes two sections:\\n  1. Original_Problem: The complete original problem statement, followed by the desired programming language for the solution code.\\n  2. Partial_Solution: The solution steps are provided, followed by a suggestion of a corrective direction to the reasoning.",
#     "intervene_prompt": "You are an expert problem solver who provides clear, comprehensive, step-by-step solutions to competitive programming problems. You are provided with the Original_Problem, including the desired programming language that you have to use in your solution code, a Partial_Solution (consisting of the correct steps and a suggestion of a corrective direction to the reasoning). Your task is to follow up on the Partial_Solution and update the reasoning content by revising the self-criticism provided and generating any subsequent steps needed to complete the solution, while leaving the Partial_Solution unchanged.\\n\\nKeep in mind the following: \\nDo not restart the reasoning content or reframe it from scratch. Continue naturally from the provided Partial_Solution.\\nProvide everything (reasoning and response) in \\u82f1\\u8bed, literally everything should be written in English\\nIf the programming language is specified in the Original_Problem, use it in the reasoning and the response (solution code). Otherwise, default to C++.\\n\\nInput includes two sections:\\n  1. Original_Problem: The complete original problem statement, followed by the desired programming language for the solution code.\\n  2. Partial_Solution: The solution steps are provided, followed by a suggestion of a corrective direction to the reasoning.\\n\\n\\n    Original Problem:\\n    Solving the given programming contest with a C++ solution.\\n\\n Problem Description\\nYou are given a square matrix \\\\\\\\(A\\\\\\\\) of size \\\\\\\\(n \\\\times n\\\\\\\\) whose elements are integers. We will denote the element on the intersection of the \\\\\\\\(i\\\\\\\\)-th row and the \\\\\\\\(j\\\\\\\\)-th column as \\\\\\\\(A_{i,j}\\\\\\\\).\\n\\nYou can perform operations on the matrix. In each operation, you can choose an integer \\\\\\\\(k\\\\\\\\), then for each index \\\\\\\\(i\\\\\\\\) (\\\\\\\\(1 \\\\leq i \\\\leq n\\\\\\\\)), swap \\\\\\\\(A_{i, k}\\\\\\\\) with \\\\\\\\(A_{k, i}\\\\\\\\). Note that cell \\\\\\\\(A_{k, k}\\\\\\\\) remains unchanged.\\n\\nFor example, for \\\\\\\\(n = 4\\\\\\\\) and \\\\\\\\(k = 3\\\\\\\\), this matrix will be transformed like this:\\n\\n\\\\begin{center}\\n  \\\\includegraphics[scale=0.6]{grid.png} \\\\\\\\\\n  \\\\small{The operation \\\\\\\\(k = 3\\\\\\\\) swaps the blue row with the green column.}\\n\\\\end{center}\\n\\nYou can perform this operation any number of times. Find the lexicographically smallest matrix\\\\\\\\(^\\\\dagger\\\\\\\\) you can obtain after performing arbitrary number of operations.\\n\\n\\\\\\\\({}^\\\\dagger\\\\\\\\) For two matrices \\\\\\\\(A\\\\\\\\) and \\\\\\\\(B\\\\\\\\) of size \\\\\\\\(n \\\\times n\\\\\\\\), let \\\\\\\\(a_{(i-1) \\\\cdot n + j} = A_{i,j}\\\\\\\\) and \\\\\\\\(b_{(i-1) \\\\cdot n + j} = B_{i,j}\\\\\\\\). Then, the matrix \\\\\\\\(A\\\\\\\\) is lexicographically smaller than the matrix \\\\\\\\(B\\\\\\\\) when there exists an index \\\\\\\\(i\\\\\\\\) (\\\\\\\\(1 \\\\leq i \\\\leq n^2\\\\\\\\)) such that \\\\\\\\(a_i < b_i\\\\\\\\) and for all indices \\\\\\\\(j\\\\\\\\) such that \\\\\\\\(1 \\\\leq j < i\\\\\\\\), \\\\\\\\(a_j = b_j\\\\\\\\).\\n\\n Input Format\\nThe first line contains a single integer \\\\\\\\(t\\\\\\\\) (\\\\\\\\(1 \\\\leq t \\\\leq 10^5\\\\\\\\)) --- the number of test cases.\\n\\nThe first line of each test case contains a single integer \\\\\\\\(n\\\\\\\\) (\\\\\\\\(1 \\\\leq n \\\\leq 1000\\\\\\\\)) --- the size of the matrix.\\n\\nThe \\\\\\\\(i\\\\\\\\)-th line of the next \\\\\\\\(n\\\\\\\\) lines contains \\\\\\\\(n\\\\\\\\) integers \\\\\\\\(A_{i, 1}, A_{i, 2}, \\\\dots, A_{i, n}\\\\\\\\) (\\\\\\\\(1 \\\\le A_{i, j} \\\\le 10^9\\\\\\\\)) --- description of the matrix \\\\\\\\(A\\\\\\\\).\\n\\nIt is guaranteed that the sum of \\\\\\\\(n^2\\\\\\\\) over all test cases does not exceed \\\\\\\\(10^6\\\\\\\\).\\n\\n\\n Output Format\\nFor each test case, print \\\\\\\\(n\\\\\\\\) lines with \\\\\\\\(n\\\\\\\\) integers each --- the lex ...
#     "total_latency_ms": -1
# }
#
# Output successfully written to /Users/bytedance/Workspace/project_rlmf/data/ALL/250626_rlmf_effective_labels_609.json
